# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
names = ["Fredy", "Nicolas", "Alexandre"]

for i in enumerate(names):
  print(i)

print(type(i))
# Out:
# (0, 'Fredy')
# (1, 'Nicolas')
# (2, 'Alexandre')
# <class 'tuple'>

# %% [markdown]
# 1. What type of object is returned as output?
# Hint: You can use `type(i)`.

# %% [markdown]
# Answer: the returned object is a tuple

# %%
for i, val in enumerate(names):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i, val in enumerate(names):
  print(val)
# Out:
# Fredy
# Nicolas
# Alexandre

# %% [markdown]
# What does `i` correspond to?
# What does `val` correspond to?
# Why is it so?

# %% [markdown]
# Answer:
# 1. i corresponds to the index which means the position of i in the list
# 2. val is the value of the element of index i
# 3. enumerate() returns both the index and the value

# %%
for val, i in enumerate(names):
  print(i)
# Out:
# Fredy
# Nicolas
# Alexandre

# %%
for val, i in enumerate(names):
  print(val)
# Out:
# 0
# 1
# 2

# %% [markdown]
# 3. This time, `i` returns first names and `val` returns numbers. Why is it so?

# %% [markdown]
# Answer:
# enumerate() is a fonction that converts names into an iterable object and returns both the index and the value of the element for each turn of the loop
#
# confusion comes from the name of the variable which contains the index (val)

# %% [markdown]
# 4. What does the built in function `enumerate` do?
# In what cases can it be useful?

# %%
te

# %% [markdown]
# Answer: enumerate() function converts what is in between brackets into an iterable object
# It is useful for tuples

# %% [markdown]
# # Mission 2

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list[8] = "Marshall"

test_list
# Out:
# ['Hi', 'my', 'name', 'is', 'hi', 'my', 'name', 'is', 'Marshall']

# %% [markdown]
# 1. What does the 8 in square brackets mean?
# What action has been performed?

# %% [markdown]
# Answer: 8 between square brackets is the 8th index of the list (the 9th element beacause indexation strats from 0)
# Here we replaced the element of index 8 by another element

# %%
for i in range(4):
  print(test_list[i])
# Out:
# Hi
# my
# name
# is

# %% [markdown]
# 2. What does `range(4)` mean?
# Why are only the first 4 elements of `test_list` displayed?

# %% [markdown]
# Answer: range() means the interval in which the loop will turnr
# in range(4), beacause there is no starting point, the loop will follow the index from 0 to 3. 4 is the ending point so it is not included. It just tells the loop that it has to stop when reaching this point.
# IN the example it displays elements of index 0 then 1 then 2 then 3D

# %%
for i in range(2,8,2):
  print(test_list[i])
# Out:
# name
# hi
# name

# %% [markdown]
# 3. What does `range(2,8,2)` mean ?
# Why are only the elements 'name', 'hi' and 'name' displayed?

# %% [markdown]
# Answer:
# range(2,8,2) means that the loop will go from the index 2 to the index 8 2 steps at a time
# What is displayed corresponds to the index which are set in the interval: index 2, 4, 6. Index 8 is the stopping point so it is not included

# %% [markdown]
# # Mission 3

# %%
numbers = [2,3,1,5,9]

for i in range(10,15):
  numbers.append(i)

numbers
# Out:
# [2, 3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 1. What does `range(10,15)` mean ?
#   What is the purpose of the method `append()` ?

# %% [markdown]
# Answer:
# range(10,15) tells to the loop the interval in which it has to turn
# Here, from index 10 to index 14 (15 is the index that stops the loop so it is not included
# append() method add one or several elements at the end of the list

# %%
del numbers[0]

numbers
# Out:
# [3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 2. What is the purpose of the `del` command?

# %% [markdown]
# Answer:
# del is a key-word which allows to supress (delete) a python object
# Here it is asked the index 0 from the lsit (numbers)
# Display shows it worked

# %% [markdown]
# # Mission 4

# %%
import random

random.randint(0,10)
# Out:
# 3

# %% [markdown]
# 1. What can the method `randint()` do ?

# %% [markdown]
# Answer:
# randint() method returns a random integer between the limits of the interval
# Here between 0 and 10 both included

# %%
numbers.insert(5, "hey hey hey")
numbers
# Out:
# [3, 1, 5, 9, 10, 'hey hey hey', 11, 12, 13, 14]

# %% [markdown]
# 2. What can the method `.insert()` do ?
# You must answer using the terms 'parameter' and 'argument'.

# %% [markdown]
# Answer:
# Insert() method inserts one or several elements in a list at a chosen position
# Function prototype is written insert(position, element) where 'position' and 'element' are the parameters
# In th eexample function arguments (reel values set into the function) are 5 and 'hey hey hey'

# %% [markdown]
# # Mission 5

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]
print(type(test_list))

test_list = " ".join(test_list)
print(type(test_list))
# Out:
# <class 'list'>
# <class 'str'>

# %% [markdown]
# 1. What can the `.join()` method do?
# What is the type of `test_list` before using `.join()`?
# What is the type of `test_list` after using `.join()`?

# %% [markdown]
# Answer:
# Here the join() method transforms the list into a string and add a space (" ") as a separator
# Before join() we have a list and after join() we have a string

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"
print(type(christmas))

x = christmas.split()
print(type(x))
# Out:
# <class 'str'>
# <class 'list'>

# %% [markdown]
# 2. What can the `.split()` method do?
# What is the type of `christmas` before using `.split()`?
# What is the type of `christmas` after using `.split()`?

# %% [markdown]
# Answer:
# split() method transforms a string into a list
# Before split() we have a string and after split() we have a list where each word is a list item

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"


christmas.split("à")
# Out:
# ["Noël c'est bien, mais attention ",
#  ' ne pas manger trop de chocolat. On le sait, mais on le fais ',
#  " chaque fois. C'est la vie"]

# %% [markdown]
# 3. Why does the `.split()` method split the `string` into 3 elements?

# %% [markdown]
# Answer:
# christmas.split("à") transforms the string into a list with "à" as a separator
# split() returns list items one by one
